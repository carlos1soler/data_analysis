# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos1soler/data_analysis/blob/main/DowJonesAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = 'https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23ebf3fb&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1320&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=DJIA&scale=left&cosd=2021-03-23&coed=2026-03-23&line_color=%230073e6&link_values=false&line_style=solid&mark_type=none&mw=3&lw=3&ost=-99999&oet=99999&mma=0&fml=a&fq=Daily%2C%20Close&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2026-03-24&revision_date=2026-03-24&nd=2016-03-24'

# %%
import pandas as pd

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      observation_date      DJIA
# 0          2021-03-23  32423.15
# 1          2021-03-24  32420.06
# 2          2021-03-25  32619.48
# 3          2021-03-26  33072.88
# 4          2021-03-29  33171.37
# ...               ...       ...
# 1300       2026-03-17  46993.26
# 1301       2026-03-18  46225.15
# 1302       2026-03-19  46021.43
# 1303       2026-03-20  45577.47
# 1304       2026-03-23  46208.47
#
# [1305 rows x 2 columns]

# %%
df.isnull().sum()
number_nulls = df.isnull().sum().sum()
print('There are ' + str(number_nulls) + ' null values in this file')
# Out:
# There are 49 null values in this file

# %%
num_row = len(df)
null_ratio = (number_nulls / num_row)*100
#print('the null ratio is ' + str(null_ratio)+ '%')
print(f'the null ratio is {null_ratio :.2f} %')
# Out:
# the null ratio is 3.75 %

# %%
# dropna()
  # dropna(axis = 1) -- drop values only from columns that contain no values.
  # dropna(thresh = 2) -- will only dropped if that threshold is met
  # fillna(value : 'new value' ) -- will fill missing value

df.dropna()

# %% [markdown]
# <H1>VISUALIZE DATA WITH GRAPHS<H1>

# %%
import seaborn as sns

sns.lineplot(df, x= 'observation_date', y = 'DJIA')
df.plot(x= 'observation_date', y = 'DJIA', kind = 'line' )
# Out:
# <Axes: xlabel='observation_date'>

# %% [markdown]
# <h1>CLEANING DATA

# %%
df = df.dropna()
df.size
df
# Out:
#      observation_date      DJIA
# 0          2021-03-23  32423.15
# 1          2021-03-24  32420.06
# 2          2021-03-25  32619.48
# 3          2021-03-26  33072.88
# 4          2021-03-29  33171.37
# ...               ...       ...
# 1300       2026-03-17  46993.26
# 1301       2026-03-18  46225.15
# 1302       2026-03-19  46021.43
# 1303       2026-03-20  45577.47
# 1304       2026-03-23  46208.47
#
# [1256 rows x 2 columns]
